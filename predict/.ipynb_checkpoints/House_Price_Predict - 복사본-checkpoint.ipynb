# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("./data/house_info_update1.csv", encoding= 'utf-8-sig', thousands=',')

# %%
# donli, danjiname, doro 삭제

# %%
df = df.drop(['donli', 'danjiname' ,'sigog', 'siheg' ,'nambang', 'cctv'], axis=1)

# %%
df = df.drop(['amenities'],axis=1)

# %%
df = df.drop(['danjicode'], axis=1)

# %%
df.head(20)
# Out:
#          danjigubn  sedesu        gukag  eill  guard  clean       food  water  \
# 0              아파트      69          NaN   1.0    3.0    1.0        NaN  부스타방식
# 1              NaN     116          NaN   NaN    NaN    NaN        NaN    NaN
# 2              NaN     122  한국주택시설관리(주)  16.0    NaN    NaN        NaN    NaN
# 3              NaN     136      광인산업(주)   3.0    0.0    2.0     차량수거방식  부스타방식
# 4              아파트     114      서일개발(주)   1.0    2.0    1.0  음식물쓰레기종량제  압력탱크식
# 5              NaN     148          NaN   1.0    2.0    1.0         기타  수도직결식
# 6              NaN     111          NaN   NaN    NaN    NaN        NaN    NaN
# 7              아파트     115      (주)동우개발   2.0    2.0    1.0  음식물쓰레기종량제  고가수조식
# 8              NaN     136          NaN   NaN    NaN    NaN        NaN    NaN
# 9   도시형 생활주택(주상복합)     187          NaN   0.0    2.0    1.0   거점장비수거방식  부스타방식
# 10            주상복합     108  (주)아스타아이비에스  11.0    3.0    4.0  음식물쓰레기종량제  부스타방식
# 11             아파트     128          NaN   NaN    NaN    NaN        NaN    NaN
# 12             NaN      96     (주)무림하우징   4.0    2.0    1.0     차량수거방식  부스타방식
# 13             NaN      88      (주)현대개발   3.0    2.0    1.0     차량수거방식  부스타방식
# 14             아파트     104  주식회사 한빛종합관리   NaN    NaN    NaN        NaN    NaN
# 15             아파트     104  주식회사 한빛종합관리   NaN    NaN    NaN        NaN    NaN
# 16             아파트     127          NaN   NaN    NaN    NaN        NaN    NaN
# 17             아파트     109    (주)현장종합관리   NaN    NaN    NaN        NaN    NaN
# 18             아파트     115      (주)아주관리   1.0    2.0    1.0  음식물쓰레기종량제  부스타방식
# 19             아파트     118      영광관리(주)   1.0    2.0    1.0     차량수거방식  부스타방식
#
#     ellbe  gisa  ...                   doro amenitiesCnt price  market  \
# 0     2.0   0.0  ...   서울특별시 광진구 아차산로36길 13            4   515      30
# 1     0.0   NaN  ...   서울특별시 서초구 방배로3길 10-3            0  1516      40
# 2     NaN   NaN  ...      서울특별시 마포구 백범로 202            1  1162      30
# 3     5.0  60.0  ...     서울특별시 강서구 공항대로 637            3  1236      10
# 4     3.0   0.0  ...      서울특별시 강서구 양천로 497            4   909     100
# 5     5.0  13.0  ...   서울특별시 강서구 등촌로13자길 74            4   584      20
# 6     NaN   NaN  ...   서울특별시 서대문구 수색로 147-1            0   727      40
# 7     5.0  27.0  ...  서울특별시 노원구 동일로239나길 31            3   320      40
# 8     NaN   NaN  ...   서울특별시 강남구 언주로122길 25            0  1069      30
# 9     2.0   8.0  ...  서울특별시 도봉구 도봉로150다길 28            2   -54      30
# 10    2.0   0.0  ...      서울특별시 관악구 관악로 195            1   404      40
# 11    NaN   NaN  ...    서울특별시 마포구 동교로39길 11            0   779      20
# 12    3.0   7.0  ...  서울특별시 동대문구 한천로58길 181            5   603      30
# 13    3.0  30.0  ...     서울특별시 마포구 독막로42길 5            3  2351      50
# 14    NaN   NaN  ...     서울특별시 성북구 종암로9길 71            0  1416      20
# 15    NaN   NaN  ...     서울특별시 성북구 종암로9길 71            0  1416      20
# 16    NaN   NaN  ...      서울특별시 관악구 호암로 541            0   551      10
# 17    NaN   NaN  ...     서울특별시 관악구 호암로16길 5            0   934      10
# 18    4.0  78.0  ...    서울특별시 노원구 석계로13길 35            2   478      40
# 19    6.0  38.0  ...    서울특별시 관악구 관악로28길 80            4   503      20
#
#     school  station  bank  café  hospital   ipji
# 0       80       20    26    87         40   283
# 1       40       20     9    31         18   158
# 2       20      250    45   145        106   596
# 3       20       50    21    46         37   184
# 4      140       50    21    47         64   422
# 5       80        0     7    11          0   118
# 6      100       70     2    14          5   231
# 7       20       20    16    51         33   180
# 8       20        0    33   119         92   294
# 9       40      100    23    45         51   289
# 10      60       50    35   127        125   437
# 11      60        0    17   456         31   584
# 12      20       20     6    12          7    95
# 13      60       60    47   185        101   503
# 14      40        0    15    27         21   123
# 15      40        0    15    27         21   123
# 16     100        0    10    13          3   136
# 17      60        0     7     7          3    87
# 18     100       40    15    41          9   245
# 19     100        0    13    58         49   240
#
# [20 rows x 22 columns]

# %%
# gu_df = df['doro'].str.split(' ').str[1]

# %%
# gu_df = pd.DataFrame(gu_df)

# %%
# gu_df.columns = ['gu']

# %%
# df = pd.concat([df, gu_df], axis =1)

# %%
# df = df.drop(['doro'], axis=1)

# %%
df.head(2)
# Out:
#   danjigubn  sedesu gukag  eill  guard  clean food  water  ellbe  gisa  ...  \
# 0       아파트      69   NaN   1.0    3.0    1.0  NaN  부스타방식    2.0   0.0  ...
# 1       NaN     116   NaN   NaN    NaN    NaN  NaN    NaN    0.0   NaN  ...
#
#                    doro amenitiesCnt price  market  school  station  bank  \
# 0  서울특별시 광진구 아차산로36길 13            4   515      30      80       20    26
# 1  서울특별시 서초구 방배로3길 10-3            0  1516      40      40       20     9
#
#    café  hospital   ipji
# 0    87         40   283
# 1    31         18   158
#
# [2 rows x 22 columns]

# %%
df = df.drop(['gukag'], axis=1)

# %%
df.columns
# Out:
# Index(['danjigubn', 'sedesu', 'eill', 'guard', 'clean', 'food', 'water',
#        'ellbe', 'gisa', 'giha', 'gucha', 'doro', 'amenitiesCnt', 'price',
#        'market', 'school', 'station', 'bank', 'café', 'hospital ', 'ipji'],
#       dtype='object')

# %%
df.describe()
# Out:
#             sedesu         eill        guard        clean        ellbe  \
# count  2453.000000  2367.000000  2364.000000  2363.000000  2339.000000
# mean    555.627803     6.373638     8.842640     5.856369    13.357845
# std     606.883995     5.363804    12.421151     6.571119    14.537546
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%     204.000000     4.000000     3.000000     2.000000     5.000000
# 50%     355.000000     5.000000     5.000000     4.000000     9.000000
# 75%     660.000000     8.000000    10.000000     7.000000    17.000000
# max    6864.000000    61.000000   234.000000    80.000000   207.000000
#
#               gisa         giha  amenitiesCnt        price       market  \
# count  2360.000000  2356.000000   2453.000000  2453.000000  2453.000000
# mean    186.560169   422.294143      4.586221   903.359967    37.586629
# std     364.334105   662.282921      2.126027   623.800696    21.143038
# min       0.000000     0.000000      0.000000 -1095.000000     0.000000
# 25%      13.000000    95.000000      3.000000   478.000000    20.000000
# 50%      66.000000   220.000000      4.000000   794.000000    30.000000
# 75%     193.000000   510.000000      6.000000  1221.000000    50.000000
# max    4500.000000  9486.000000     11.000000  5532.000000   130.000000
#
#             school      station         bank         café    hospital   \
# count  2453.000000  2453.000000  2453.000000  2453.000000  2453.000000
# mean     57.007746    21.455361    16.104770    48.852833    31.763555
# std      36.292477    28.712903    10.358069    43.422832    29.668690
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%      40.000000     0.000000     9.000000    22.000000    13.000000
# 50%      60.000000    20.000000    14.000000    37.000000    25.000000
# 75%      80.000000    40.000000    21.000000    61.000000    42.000000
# max     200.000000   250.000000    74.000000   555.000000   380.000000
#
#               ipji
# count  2453.000000
# mean    212.770893
# std     102.004676
# min       4.000000
# 25%     146.000000
# 50%     198.000000
# 75%     262.000000
# max     875.000000

# %%
df.isnull().sum()
# Out:
# danjigubn        48
# sedesu            0
# eill             86
# guard            89
# clean            90
# food            157
# water           104
# ellbe           114
# gisa             93
# giha             97
# gucha           101
# doro              0
# amenitiesCnt      0
# price             0
# market            0
# school            0
# station           0
# bank              0
# café              0
# hospital          0
# ipji              0
# dtype: int64

# %%
# df = df.dropna(subset=['ellbe', 'gisa', 'giha'])

# %%
df = df.dropna(thresh=23)

# %%
df.isnull().sum()
# Out:
# danjigubn       0.0
# sedesu          0.0
# eill            0.0
# guard           0.0
# clean           0.0
# food            0.0
# water           0.0
# ellbe           0.0
# gisa            0.0
# giha            0.0
# gucha           0.0
# doro            0.0
# amenitiesCnt    0.0
# price           0.0
# market          0.0
# school          0.0
# station         0.0
# bank            0.0
# café            0.0
# hospital        0.0
# ipji            0.0
# dtype: float64

# %%
# 나중에 수치데이터로 바꿔줘야 할듯

# %%
df.loc[:,['danjigubn']] = df.loc[:,['danjigubn']].fillna('아파트')

# %%
# df['sigog'] = df['sigog'].str.replace('주','')

# %%
# df["sigog"] = df["sigog"].str.replace(pat=r'[^\w]', repl=r'', regex=True)

# %%
df = df.dropna()
df.count()
# Out:
# danjigubn       2235
# sedesu          2235
# eill            2235
# guard           2235
# clean           2235
# food            2235
# water           2235
# ellbe           2235
# gisa            2235
# giha            2235
# gucha           2235
# amenitiesCnt    2235
# areadaprice     2235
# market          2235
# school          2235
# station         2235
# bank            2235
# cafe            2235
# hospital        2235
# gu              2235
# dtype: int64

# %%
# df['sigog'].value_counts()[:50]

# %%
#df.loc[~((df['sigog'] == '현대건설') | (df['sigog'] == '삼성물산') | (df['sigog']=='현대산업개발') | (df['sigog'] == '대우건설')), 'sigog'] = "other"

# %%
# df['sigog'].value_counts()

# %%
categories = df.columns[df.dtypes=="object"]
print(categories)
# Out:
# Index(['danjigubn', 'food', 'water', 'gucha', 'gu'], dtype='object')

# %%
from sklearn.preprocessing import LabelEncoder

# %%
for cat in categories:
    le = LabelEncoder()
    print(cat)
    if df[cat].dtypes == "object":
        le = le.fit(df[cat])
        df[cat] = le.transform(df[cat])
# Out:
# danjigubn
# food
# water
# gucha
# gu

# %%
df.dtypes
# Out:
# danjigubn         int32
# sedesu            int64
# eill            float64
# guard           float64
# clean           float64
# food              int32
# water             int32
# ellbe           float64
# gisa            float64
# giha            float64
# gucha             int32
# amenitiesCnt      int64
# areadaprice     float64
# market            int64
# school            int64
# station           int64
# bank              int64
# cafe              int64
# hospital          int64
# gu                int32
# dtype: object

# %%
df
# Out:
#       danjigubn  sedesu  eill  guard  clean  food  water  ellbe   gisa  \
# 0             4     176   6.0    4.0    1.0     2      2    3.0    0.0
# 1             4     155   3.0    2.0    2.0     3      2    2.0    0.0
# 2             2     644   6.0    8.0    7.0     2      0   20.0  226.0
# 3             2     168  13.0    6.0    9.0     2      2    6.0   13.0
# 4             2    2296  23.0   31.0   34.0     0      2   83.0   10.0
# ...         ...     ...   ...    ...    ...   ...    ...    ...    ...
# 2415          2     192   3.0    2.0    2.0     2      2    7.0   83.0
# 2416          2     824   9.0   18.0    7.0     2      3   16.0  600.0
# 2417          2     111   1.0    2.0    1.0     3      2    4.0    6.0
# 2418          2     103   4.0    2.0    1.0     2      0    1.0    0.0
# 2419          2     287   4.0    5.0    2.0     0      2   13.0  198.0
#
#         giha  gucha  amenitiesCnt  areadaprice  market  school  station  bank  \
# 0      176.0      0             1       4395.0       5       4        2    40
# 1      123.0      0             1       3480.0       6       4        2    43
# 2      458.0      0             3       7701.0       5       0        2    48
# 3      276.0      0             1       3141.0       8       0        3    70
# 4     3951.0      1             8      10629.0       4       5        3     6
# ...      ...    ...           ...          ...     ...     ...      ...   ...
# 2415    53.0      0             4       2087.0       5       2        0    16
# 2416     0.0      0             3       3164.0       4       1        1    15
# 2417   114.0      0             4       2095.0       2       2        0    21
# 2418    86.0      0             3       1752.0       3       3        1     9
# 2419    23.0      0             3       1843.0       2       3        1     5
#
#       cafe  hospital  gu
# 0      107        91   0
# 1      122        98   0
# 2      174       294   0
# 3      317       313   0
# 4       12        11   0
# ...    ...       ...  ..
# 2415    32        42   9
# 2416    58        35   9
# 2417    48        33   9
# 2418    25         7   9
# 2419     8         4   9
#
# [2235 rows x 20 columns]

# %%
df_corr = df.corr()

# %%
df_corr
# Out:
#               danjigubn    sedesu      eill     guard     clean      food  \
# danjigubn      1.000000 -0.103248  0.085421 -0.027706  0.022391 -0.044286
# sedesu        -0.103248  1.000000  0.849297  0.750780  0.913108 -0.013841
# eill           0.085421  0.849297  1.000000  0.764075  0.909667 -0.034332
# guard         -0.027706  0.750780  0.764075  1.000000  0.718625 -0.007938
# clean          0.022391  0.913108  0.909667  0.718625  1.000000 -0.030051
# food          -0.044286 -0.013841 -0.034332 -0.007938 -0.030051  1.000000
# water          0.067491  0.032893  0.032073 -0.006762  0.073599  0.012783
# ellbe         -0.106523  0.845579  0.756702  0.676472  0.824755 -0.031301
# gisa          -0.089423  0.540716  0.504520  0.729810  0.425086  0.017477
# giha           0.011999  0.705146  0.650954  0.344847  0.803848 -0.054653
# gucha          0.139296  0.102359  0.160386 -0.021023  0.211423 -0.077739
# amenitiesCnt  -0.110712  0.311534  0.280241  0.120091  0.347022 -0.066682
# areadaprice   -0.029397  0.248672  0.344972  0.280315  0.337476 -0.058189
# market         0.072456  0.087464  0.135791  0.127064  0.106954 -0.032171
# school        -0.066987  0.114588  0.093792  0.092361  0.086771  0.041734
# station        0.158759 -0.009649  0.073517  0.040428  0.051798 -0.001193
# bank           0.343212 -0.103223  0.004016 -0.029459 -0.029119 -0.040928
# cafe           0.284725 -0.144401 -0.052954 -0.068515 -0.072014 -0.033975
# hospital       0.192228 -0.022057  0.046136  0.042398  0.021961 -0.004410
# gu             0.048671 -0.027027 -0.006371 -0.007658  0.002293 -0.072389
#
#                  water     ellbe      gisa      giha     gucha  amenitiesCnt  \
# danjigubn     0.067491 -0.106523 -0.089423  0.011999  0.139296     -0.110712
# sedesu        0.032893  0.845579  0.540716  0.705146  0.102359      0.311534
# eill          0.032073  0.756702  0.504520  0.650954  0.160386      0.280241
# guard        -0.006762  0.676472  0.729810  0.344847 -0.021023      0.120091
# clean         0.073599  0.824755  0.425086  0.803848  0.211423      0.347022
# food          0.012783 -0.031301  0.017477 -0.054653 -0.077739     -0.066682
# water         1.000000  0.082899 -0.086840  0.119057  0.242384      0.185922
# ellbe         0.082899  1.000000  0.470973  0.686207  0.162682      0.333277
# gisa         -0.086840  0.470973  1.000000 -0.082309 -0.161320     -0.053779
# giha          0.119057  0.686207 -0.082309  1.000000  0.325634      0.428317
# gucha         0.242384  0.162682 -0.161320  0.325634  1.000000      0.433019
# amenitiesCnt  0.185922  0.333277 -0.053779  0.428317  0.433019      1.000000
# areadaprice   0.044497  0.231795  0.100750  0.275451  0.214239      0.237208
# market        0.026712  0.046544  0.095178  0.040914 -0.024367     -0.030720
# school       -0.026457  0.101038  0.079591  0.046271 -0.065251      0.039336
# station      -0.006616 -0.034437  0.013052  0.019628  0.046743     -0.038524
# bank          0.011928 -0.129614 -0.064073 -0.027295  0.043451     -0.146217
# cafe         -0.002084 -0.160382 -0.099879 -0.046872  0.053660     -0.136615
# hospital      0.004960 -0.054263  0.024689 -0.009255  0.011637     -0.114619
# gu            0.024656 -0.004859 -0.030245  0.000636  0.086407      0.024386
#
#               areadaprice    market    school   station      bank      cafe  \
# danjigubn       -0.029397  0.072456 -0.066987  0.158759  0.343212  0.284725
# sedesu           0.248672  0.087464  0.114588 -0.009649 -0.103223 -0.144401
# eill             0.344972  0.135791  0.093792  0.073517  0.004016 -0.052954
# guard            0.280315  0.127064  0.092361  0.040428 -0.029459 -0.068515
# clean            0.337476  0.106954  0.086771  0.051798 -0.029119 -0.072014
# food            -0.058189 -0.032171  0.041734 -0.001193 -0.040928 -0.033975
# water            0.044497  0.026712 -0.026457 -0.006616  0.011928 -0.002084
# ellbe            0.231795  0.046544  0.101038 -0.034437 -0.129614 -0.160382
# gisa             0.100750  0.095178  0.079591  0.013052 -0.064073 -0.099879
# giha             0.275451  0.040914  0.046271  0.019628 -0.027295 -0.046872
# gucha            0.214239 -0.024367 -0.065251  0.046743  0.043451  0.053660
# amenitiesCnt     0.237208 -0.030720  0.039336 -0.038524 -0.146217 -0.136615
# areadaprice      1.000000  0.257503 -0.003469  0.262386  0.124232  0.145891
# market           0.257503  1.000000  0.119671  0.191321  0.297388  0.237239
# school          -0.003469  0.119671  1.000000  0.016091 -0.088673 -0.135469
# station          0.262386  0.191321  0.016091  1.000000  0.424195  0.396538
# bank             0.124232  0.297388 -0.088673  0.424195  1.000000  0.727404
# cafe             0.145891  0.237239 -0.135469  0.396538  0.727404  1.000000
# hospital         0.217417  0.319327 -0.063848  0.273241  0.679457  0.632609
# gu              -0.063063 -0.074255 -0.047985  0.132932 -0.026026 -0.018173
#
#               hospital        gu
# danjigubn     0.192228  0.048671
# sedesu       -0.022057 -0.027027
# eill          0.046136 -0.006371
# guard         0.042398 -0.007658
# clean         0.021961  0.002293
# food         -0.004410 -0.072389
# water         0.004960  0.024656
# ellbe        -0.054263 -0.004859
# gisa          0.024689 -0.030245
# giha         -0.009255  0.000636
# gucha         0.011637  0.086407
# amenitiesCnt -0.114619  0.024386
# areadaprice   0.217417 -0.063063
# market        0.319327 -0.074255
# school       -0.063848 -0.047985
# station       0.273241  0.132932
# bank          0.679457 -0.026026
# cafe          0.632609 -0.018173
# hospital      1.000000 -0.136064
# gu           -0.136064  1.000000

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.figure(figsize=(15,15))
sns.heatmap(df_corr, vmax=1, vmin=-1, center=0, annot=True)
# Out:
# <AxesSubplot:>

# %%
train_df_le = df[~df['areadaprice'].isnull()]
test_df_le = df[df['areadaprice'].isnull()]

# %%
import lightgbm as lgb

# %%
from sklearn.model_selection import KFold
folds = 3
kf = KFold(n_splits = folds)

# %%
lgbm_params = {
    "objective":"regression",
    "random_seed":1234
}

# %%
train_X = train_df_le.drop(['areadaprice'], axis=1)
train_Y = train_df_le['areadaprice']

# %%
from sklearn.metrics import mean_squared_error
import numpy as np

# %%
models = []
rmses = []
oof = np.zeros(len(train_X))

for train_index, val_index in kf.split(train_X):
    X_train = train_X.iloc[train_index]
    X_valid = train_X.iloc[val_index]
    y_train = train_Y.iloc[train_index]
    y_valid = train_Y.iloc[val_index]
    
    lgb_train = lgb.Dataset(X_train, y_train)
    lgb_eval = lgb.Dataset(X_valid, y_valid, reference=lgb_train)
    
    model_lgb = lgb.train(lgbm_params,
                         lgb_train,
                          valid_sets = lgb_eval,
                         num_boost_round=100,
                         early_stopping_rounds=20,
                         verbose_eval = 10)
    
    y_pred = model_lgb.predict(X_valid, num_iteration=model_lgb.best_iteration)
    tmp_rmse = np.sqrt(mean_squared_error(np.log(y_valid), np.log(y_pred)))
    print(tmp_rmse)
    
    models.append(model_lgb)
    rmses.append(tmp_rmse)
    oof[val_index] = y_pred
# Out:
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000206 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1284
# [LightGBM] [Info] Number of data points in the train set: 1490, number of used features: 19
# [LightGBM] [Info] Start training from score 4113.232282
# Training until validation scores don't improve for 20 rounds
# [10]	valid_0's l2: 4.84873e+06
# [20]	valid_0's l2: 5.06202e+06
# Early stopping, best iteration is:
# [1]	valid_0's l2: 4.3165e+06
# 0.4089230639741789
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000217 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1308
# [LightGBM] [Info] Number of data points in the train set: 1490, number of used features: 19
# [LightGBM] [Info] Start training from score 4330.480537
# Training until validation scores don't improve for 20 rounds
# [10]	valid_0's l2: 1.2894e+06
# [20]	valid_0's l2: 1.03471e+06
# [30]	valid_0's l2: 929211
# [40]	valid_0's l2: 901418
# [50]	valid_0's l2: 877475
# [60]	valid_0's l2: 865720
# [70]	valid_0's l2: 860162
# [80]	valid_0's l2: 861816
# [90]	valid_0's l2: 861561
# Early stopping, best iteration is:
# [70]	valid_0's l2: 860162
# 0.2172702233622798
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000173 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1310
# [LightGBM] [Info] Number of data points in the train set: 1490, number of used features: 19
# [LightGBM] [Info] Start training from score 4306.392285
# Training until validation scores don't improve for 20 rounds
# [10]	valid_0's l2: 1.37762e+06
# [20]	valid_0's l2: 1.13958e+06
# [30]	valid_0's l2: 1.02514e+06
# [40]	valid_0's l2: 985895
# [50]	valid_0's l2: 978561
# [60]	valid_0's l2: 983887
# [70]	valid_0's l2: 976496
# [80]	valid_0's l2: 968864
# [90]	valid_0's l2: 962370
# [100]	valid_0's l2: 959938
# Did not meet early stopping. Best iteration is:
# [95]	valid_0's l2: 958544
# 0.22761665686893423
# C:\Users\sonsj\anaconda3\lib\site-packages\lightgbm\engine.py:181: UserWarning: 'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. Pass 'early_stopping()' callback via 'callbacks' argument instead.
#   _log_warning("'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. "
# C:\Users\sonsj\anaconda3\lib\site-packages\lightgbm\engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# C:\Users\sonsj\anaconda3\lib\site-packages\lightgbm\engine.py:181: UserWarning: 'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. Pass 'early_stopping()' callback via 'callbacks' argument instead.
#   _log_warning("'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. "
# C:\Users\sonsj\anaconda3\lib\site-packages\lightgbm\engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# C:\Users\sonsj\anaconda3\lib\site-packages\lightgbm\engine.py:181: UserWarning: 'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. Pass 'early_stopping()' callback via 'callbacks' argument instead.
#   _log_warning("'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. "
# C:\Users\sonsj\anaconda3\lib\site-packages\lightgbm\engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "

# %%
for model in models:
    lgb.plot_importance(model, importance_type='gain', max_num_features=5)
