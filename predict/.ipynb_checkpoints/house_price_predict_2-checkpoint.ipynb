# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("./data/final01.csv", encoding= 'utf-8-sig', thousands=',')

# %%
df
# Out:
#      danjigubn  sedesu nambang      sigog                 siheg        gukag  \
# 0         주상복합     176    개별난방       SK건설                  SK건설  (주)아스타아이비에스
# 1         주상복합     155    개별난방       대우건설                  대우건설          NaN
# 2          아파트     644    개별난방      신동아건설        논현동공무원아파트재건축조합         광인산업
# 3          아파트     168    개별난방       대우건설                플러스하우징    국제경보산업(주)
# 4          아파트    2296    지역난방    삼성물산(주)  개포시영아파트 주택재건축 정비사업조합     (주)타워피엠씨
# ...        ...     ...     ...        ...                   ...          ...
# 2415       아파트     192    개별난방       현대건설                  현대건설       세화종합관리
# 2416       아파트     824    개별난방       한양건설                  한양건설          NaN
# 2417       아파트     111    개별난방       수산건설                  수산건설          NaN
# 2418       아파트     103    개별난방       염광건설                  염광건설      (주)동우개발
# 2419       아파트     287    개별난방  현대산업개발(주)          (주)고려외 6개 조합    서림주택관리(주)
#
#       eill  guard  danjicode  clean  ... donli   danjiname  amenitiesCnt  \
# 0      6.0    4.0  A13527018    1.0  ...   도곡동   양재SK허브프리모             1
# 1      3.0    2.0  A13527001    2.0  ...   도곡동    도곡동양재디오빌             1
# 2      6.0    8.0  A13501004    7.0  ...   논현동       논현신동아             3
# 3     13.0    6.0  A13508003    9.0  ...   역삼동    대우디오빌플러스             1
# 4     23.0   31.0  A10024564   34.0  ...   개포동   개포래미안포레스트             8
# ...    ...    ...        ...    ...  ...   ...         ...           ...
# 2415   3.0    2.0  A13286002    2.0  ...   쌍문동      쌍문현대2차             4
# 2416   9.0   18.0  A13203303    7.0  ...   쌍문동      쌍문한양1차             3
# 2417   1.0    2.0  A13275001    1.0  ...    창동  창동수산트리플아파트             4
# 2418   4.0    2.0  A10026175    1.0  ...   쌍문동     쌍문염광아파트             3
# 2419   4.0    5.0  A13287801    2.0  ...   쌍문동      쌍문현대3차             3
#
#       areadaprice  market  school station bank cafe hospital
# 0          4395.0       5       4       2   40  107       91
# 1          3480.0       6       4       2   43  122       98
# 2          7701.0       5       0       2   48  174      294
# 3          3141.0       8       0       3   70  317      313
# 4         10629.0       4       5       3    6   12       11
# ...           ...     ...     ...     ...  ...  ...      ...
# 2415       2087.0       5       2       0   16   32       42
# 2416       3164.0       4       1       1   15   58       35
# 2417       2095.0       2       2       0   21   48       33
# 2418       1752.0       3       3       1    9   25        7
# 2419       1843.0       2       3       1    5    8        4
#
# [2420 rows x 29 columns]

# %%
categories = df.columns[df.dtypes=='object']
print(categories)
# Out:
# Index(['danjigubn', 'nambang', 'sigog', 'siheg', 'gukag', 'danjicode', 'food',
#        'water', 'gucha', 'amenities', 'doro', 'donli', 'danjiname'],
#       dtype='object')

# %%
df = df.drop(['gukag'], axis=1)

# %%
# 결측치 수가 상위 10인 변수 확인하기
df.isnull().sum().sort_values(ascending=False).head(10)
# Out:
# food         151
# amenities    125
# ellbe        112
# water        103
# gucha        100
# cctv          96
# giha          95
# gisa          92
# clean         89
# guard         88
# dtype: int64

# %%
df.food.value_counts()
# Out:
# 음식물쓰레기종량제    1435
# 차량수거방식        555
# 거점장비수거방식      179
# 기타            100
# Name: food, dtype: int64

# %%
df.describe().T
# Out:
#                count         mean          std     min      25%     50%  \
# sedesu        2420.0   558.643802   637.739052     0.0   203.75   355.5
# eill          2337.0     6.467266     5.569824     0.0     4.00     5.0
# guard         2332.0     8.781304    12.317661     0.0     3.00     5.0
# clean         2331.0     6.063320     7.045076     0.0     2.00     4.0
# ellbe         2308.0    13.677643    15.303577     0.0     5.00     9.0
# gisa          2328.0   178.275773   359.284075     0.0     8.00    61.0
# giha          2325.0   451.784086   743.284927     0.0   100.00   229.0
# cctv          2324.0   116.956670   165.406801     0.0    39.00    68.0
# amenitiesCnt  2420.0     4.696694     2.238689     0.0     3.00     4.0
# areadaprice   2420.0  4223.825992  1744.297967  1096.0  2985.00  3847.2
# market        2420.0     3.754959     2.118804     0.0     2.00     3.0
# school        2420.0     2.838017     1.804237     0.0     2.00     3.0
# station       2420.0     1.794628     1.481724     0.0     1.00     2.0
# bank          2420.0    16.143388    10.423390     0.0     9.00    14.0
# cafe          2420.0    49.682645    43.828965     0.0    22.00    38.0
# hospital      2420.0    32.024380    29.954889     0.0    13.00    26.0
#
#                   75%      max
# sedesu         660.00   9510.0
# eill             8.00     65.0
# guard           10.00    234.0
# clean            7.00    105.0
# ellbe           18.00    207.0
# gisa           181.00   4500.0
# giha           527.00  12096.0
# cctv           128.25   2685.0
# amenitiesCnt     6.00     11.0
# areadaprice   5059.55  12348.0
# market           5.00     12.0
# school           4.00     10.0
# station          3.00     10.0
# bank            21.00     74.0
# cafe            62.00    554.0
# hospital        42.00    380.0

# %%
# 수치데이터만 추출하기

df_num = df.select_dtypes(include=[np.number])
df_num
# Out:
#       sedesu  eill  guard  clean  ellbe   gisa    giha    cctv  amenitiesCnt  \
# 0        176   6.0    4.0    1.0    3.0    0.0   176.0    40.0             1
# 1        155   3.0    2.0    2.0    2.0    0.0   123.0    46.0             1
# 2        644   6.0    8.0    7.0   20.0  226.0   458.0    73.0             3
# 3        168  13.0    6.0    9.0    6.0   13.0   276.0    48.0             1
# 4       2296  23.0   31.0   34.0   83.0   10.0  3951.0  1058.0             8
# ...      ...   ...    ...    ...    ...    ...     ...     ...           ...
# 2415     192   3.0    2.0    2.0    7.0   83.0    53.0    28.0             4
# 2416     824   9.0   18.0    7.0   16.0  600.0     0.0    50.0             3
# 2417     111   1.0    2.0    1.0    4.0    6.0   114.0    28.0             4
# 2418     103   4.0    2.0    1.0    1.0    0.0    86.0     6.0             3
# 2419     287   4.0    5.0    2.0   13.0  198.0    23.0    48.0             3
#
#       areadaprice  market  school  station  bank  cafe  hospital
# 0          4395.0       5       4        2    40   107        91
# 1          3480.0       6       4        2    43   122        98
# 2          7701.0       5       0        2    48   174       294
# 3          3141.0       8       0        3    70   317       313
# 4         10629.0       4       5        3     6    12        11
# ...           ...     ...     ...      ...   ...   ...       ...
# 2415       2087.0       5       2        0    16    32        42
# 2416       3164.0       4       1        1    15    58        35
# 2417       2095.0       2       2        0    21    48        33
# 2418       1752.0       3       3        1     9    25         7
# 2419       1843.0       2       3        1     5     8         4
#
# [2420 rows x 16 columns]

# %%
num_features = sorted(list(set(df_num)))
num_features
# Out:
# ['amenitiesCnt',
#  'areadaprice',
#  'bank',
#  'cafe',
#  'cctv',
#  'clean',
#  'eill',
#  'ellbe',
#  'giha',
#  'gisa',
#  'guard',
#  'hospital',
#  'market',
#  'school',
#  'sedesu',
#  'station']

# %%
df_num_rs = df_num[num_features]

# %%
# 다수의 데이터가 0인 변수 확인하기

for col in num_features:
    if df_num_rs.describe()[col]['25%'] == 0:
        print(col, len(df_num_rs[df_num_rs[col]==0]))

# %%
# 특정 값만 가지는 변수 확인하기

for col in num_features:
    if df_num_rs[col].nunique()<15:
        print(col, df_num_rs[col].nunique())
# Out:
# amenitiesCnt 12
# market 13
# school 11
# station 11

# %%
# 이상치가 있는지 확인하기

for col in num_features:
    tmp_df = df_num_rs[(df_num_rs[col] > df_num_rs[col].mean() + df_num_rs[col].std() *3) | (df_num_rs[col] < df_num_rs[col].mean() - df_num_rs[col].std() *3)]
                       
    print(col, len(tmp_df))
# Out:
# amenitiesCnt 0
# areadaprice 41
# bank 40
# cafe 46
# cctv 38
# clean 42
# eill 45
# ellbe 43
# giha 34
# gisa 52
# guard 45
# hospital 32
# market 16
# school 13
# sedesu 45
# station 13

# %%
# 이상치를 포함하고 있는 변수 분포를 시각화하기

df.plot.scatter(x='bank', y='areadaprice')
# Out:
# <AxesSubplot:xlabel='bank', ylabel='areadaprice'>

# %%
df.plot.scatter(x='sedesu', y='areadaprice')
# Out:
# <AxesSubplot:xlabel='sedesu', ylabel='areadaprice'>

# %%
df.plot.scatter(x='station', y='areadaprice')
# Out:
# <AxesSubplot:xlabel='station', ylabel='areadaprice'>

# %%
df[df['station'] > 9]
# Out:
#            danjigubn  sedesu nambang      sigog     siheg  eill  guard  \
# 1433  도시형 생활주택(주상복합)     157    개별난방  (주)오렌지이앤씨  케이비부동산신탁   1.0    0.0
#
#       danjicode  clean       food  ... donli   danjiname  amenitiesCnt  \
# 1433  A10024327    1.0  음식물쓰레기종량제  ...   오장동  오렌지카운티 을지로             1
#
#       areadaprice  market school station bank cafe hospital
# 1433       5016.0       1      2      10   39  104       37
#
# [1 rows x 28 columns]
