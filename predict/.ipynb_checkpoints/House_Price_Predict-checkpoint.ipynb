# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("./data/final01.csv", encoding= 'utf-8-sig', thousands=',')

# %%
# donli, danjiname, doro 삭제

# %%
df = df.drop(['danjiname', 'donli'], axis=1)

# %%
df = df.drop(['amenities'],axis=1)

# %%
df = df.drop(['danjicode'], axis=1)

# %%
df.head(20)
# Out:
#    danjigubn  sedesu nambang             sigog                 siheg  \
# 0       주상복합     176    개별난방              SK건설                  SK건설
# 1       주상복합     155    개별난방              대우건설                  대우건설
# 2        아파트     644    개별난방             신동아건설        논현동공무원아파트재건축조합
# 3        아파트     168    개별난방              대우건설                플러스하우징
# 4        아파트    2296    지역난방           삼성물산(주)  개포시영아파트 주택재건축 정비사업조합
# 5        아파트     416    지역난방         현대산업개발(주)                    현대
# 6        아파트     405    지역난방              우성건설                  우성건설
# 7        아파트     198    지역난방           현대건설(주)               현대건설(주)
# 8        아파트     261    지역난방              우성건설            영동전화국 주택조합
# 9        아파트    1060    지역난방           현대건설(주)                대한주택공사
# 10       아파트     900    지역난방              주택공사                  주택공사
# 11       아파트     822    지역난방              삼익건설                도시개발공사
# 12       아파트     212    지역난방              화엄건설                  LG건설
# 13       아파트    1753    지역난방     성원건설.진덕산업주식회사           서울특별시도시개발공사
# 14       아파트     802    지역난방             (주)우성                 (주)우성
# 15       아파트     142    지역난방                현대                    현대
# 16       아파트     364    지역난방              한신공영                  한신공영
# 17       아파트     850    지역난방              삼성물산          현대아파트 재건축 조합
# 18       아파트     740    지역난방            남광, 대우              남광토건, 대우
# 19       아파트     570    지역난방  (주)건영,삼익주택,라이프주택    건영종합건설, 삼익주택,라이프주택
#
#           gukag  eill  guard  clean       food  ... gucha  \
# 0   (주)아스타아이비에스   6.0    4.0    1.0  음식물쓰레기종량제  ...     무
# 1           NaN   3.0    2.0    2.0     차량수거방식  ...     무
# 2          광인산업   6.0    8.0    7.0  음식물쓰레기종량제  ...     무
# 3     국제경보산업(주)  13.0    6.0    9.0  음식물쓰레기종량제  ...     무
# 4      (주)타워피엠씨  23.0   31.0   34.0   거점장비수거방식  ...     유
# 5           NaN   7.0   16.0    6.0     차량수거방식  ...     무
# 6           NaN   7.0   20.0    5.0     차량수거방식  ...     무
# 7       우리관리(주)   5.0    8.0    3.0     차량수거방식  ...     무
# 8   한국주택시설관리(주)   5.0    7.0    2.0  음식물쓰레기종량제  ...     무
# 9     서림주택관리(주)  12.0   19.0   10.0     차량수거방식  ...     무
# 10         자치관리  12.0   18.0    8.0  음식물쓰레기종량제  ...     무
# 11  한국주택시설관리(주)   7.0   12.0    7.0  음식물쓰레기종량제  ...     무
# 12          NaN   6.0    7.0    4.0  음식물쓰레기종량제  ...     무
# 13   남경종합관리(주)l  11.0   28.0   12.0   거점장비수거방식  ...     무
# 14          NaN   9.0   13.0    9.0  음식물쓰레기종량제  ...     유
# 15    세화종합관리(주)   6.0    2.0    2.0  음식물쓰레기종량제  ...     유
# 16          NaN   6.0    8.0    3.0     차량수거방식  ...     무
# 17      우리관리(주)   9.0    8.0   10.0  음식물쓰레기종량제  ...     유
# 18    한국주택관리(주)   8.0   14.0    7.0  음식물쓰레기종량제  ...     무
# 19          NaN   8.0    9.0    7.0  음식물쓰레기종량제  ...     무
#
#                      doro  amenitiesCnt  areadaprice  market school station  \
# 0      서울특별시 강남구 강남대로 240             1       4395.0       5      4       2
# 1      서울특별시 강남구 강남대로 256             1       3480.0       6      4       2
# 2   서울특별시 강남구 강남대로146길 28             3       7701.0       5      0       2
# 3    서울특별시 강남구 강남대로84길 33             1       3141.0       8      0       3
# 4       서울특별시 강남구 개포로 264             8      10629.0       4      5       3
# 5       서울특별시 강남구 개포로 303             4       6007.0       5      4       1
# 6       서울특별시 강남구 개포로 307             3       6752.5       4      5       2
# 7       서울특별시 강남구 개포로 409             3       3930.0       9      8       5
# 8       서울특별시 강남구 개포로 411             3       8290.0       8      7       5
# 9       서울특별시 강남구 개포로 516             3       9815.7       5      3       2
# 10      서울특별시 강남구 개포로 516             4       9815.7       5      3       2
# 11   서울특별시 강남구 개포로109길 21             3      10028.0       4      3       3
# 12   서울특별시 강남구 개포로109길 69             5       4703.0       4      2       3
# 13    서울특별시 강남구 개포로109길 9             5       9796.5       4      3       3
# 14   서울특별시 강남구 개포로110길 15             4       8301.8       4      4       3
# 15   서울특별시 강남구 개포로110길 21             4       6213.0       5      4       2
# 16   서울특별시 강남구 개포로110길 43             5       6441.0       5      4       2
# 17   서울특별시 강남구 개포로110길 50            10       9413.5       5      4       2
# 18    서울특별시 강남구 광평로10길 15             4       8139.0       1      4       1
# 19     서울특별시 강남구 광평로10길 6             4       7438.9       1      0       1
#
#     bank  cafe  hospital
# 0     40   107        91
# 1     43   122        98
# 2     48   174       294
# 3     70   317       313
# 4      6    12        11
# 5      7     6         7
# 6      9    10        11
# 7      1     6         1
# 8      6    11        17
# 9      7    15        21
# 10     7    15        21
# 11    11    21        19
# 12    13    18        18
# 13    11    21        19
# 14    12    34        36
# 15    11    34        35
# 16    13    40        35
# 17    12    39        35
# 18     7     7        15
# 19     0     1         3
#
# [20 rows x 25 columns]

# %%
df.columns
# Out:
# Index(['danjigubn', 'sedesu', 'nambang', 'sigog', 'siheg', 'gukag', 'eill',
#        'guard', 'clean', 'food', 'water', 'ellbe', 'gisa', 'giha', 'cctv',
#        'gucha', 'doro', 'amenitiesCnt', 'areadaprice', 'market', 'school',
#        'station', 'bank', 'cafe', 'hospital'],
#       dtype='object')

# %%
# gu_df = df['doro'].str.split(' ').str[1]
# gu_df = pd.DataFrame(gu_df)

# %%
# gu_df.columns = ["gu"]

# %%
# df = pd.concat([df, gu_df], axis=1)

# %%
# df['gu'].value_counts()

# %%
df.describe()
# Out:
#             sedesu         eill        guard        clean        ellbe  \
# count  2420.000000  2337.000000  2332.000000  2331.000000  2308.000000
# mean    558.643802     6.467266     8.781304     6.063320    13.677643
# std     637.739052     5.569824    12.317661     7.045076    15.303577
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%     203.750000     4.000000     3.000000     2.000000     5.000000
# 50%     355.500000     5.000000     5.000000     4.000000     9.000000
# 75%     660.000000     8.000000    10.000000     7.000000    18.000000
# max    9510.000000    65.000000   234.000000   105.000000   207.000000
#
#               gisa          giha         cctv  amenitiesCnt   areadaprice  \
# count  2328.000000   2325.000000  2324.000000   2420.000000   2420.000000
# mean    178.275773    451.784086   116.956670      4.696694   4223.825992
# std     359.284075    743.284927   165.406801      2.238689   1744.297967
# min       0.000000      0.000000     0.000000      0.000000   1096.000000
# 25%       8.000000    100.000000    39.000000      3.000000   2985.000000
# 50%      61.000000    229.000000    68.000000      4.000000   3847.200000
# 75%     181.000000    527.000000   128.250000      6.000000   5059.550000
# max    4500.000000  12096.000000  2685.000000     11.000000  12348.000000
#
#             market       school      station         bank         cafe  \
# count  2420.000000  2420.000000  2420.000000  2420.000000  2420.000000
# mean      3.754959     2.838017     1.794628    16.143388    49.682645
# std       2.118804     1.804237     1.481724    10.423390    43.828965
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%       2.000000     2.000000     1.000000     9.000000    22.000000
# 50%       3.000000     3.000000     2.000000    14.000000    38.000000
# 75%       5.000000     4.000000     3.000000    21.000000    62.000000
# max      12.000000    10.000000    10.000000    74.000000   554.000000
#
#           hospital
# count  2420.000000
# mean     32.024380
# std      29.954889
# min       0.000000
# 25%      13.000000
# 50%      26.000000
# 75%      42.000000
# max     380.000000

# %%
df = df.drop(['doro'], axis=1)

# %%
df.isnull().sum()
# Out:
# danjigubn        51
# sedesu            0
# nambang          15
# sigog            54
# siheg            56
# gukag           334
# eill             83
# guard            88
# clean            89
# food            151
# water           103
# ellbe           112
# gisa             92
# giha             95
# cctv             96
# gucha           100
# amenitiesCnt      0
# areadaprice       0
# market            0
# school            0
# station           0
# bank              0
# cafe              0
# hospital          0
# dtype: int64

# %%
# df = df.dropna(subset=['ellbe', 'gisa', 'giha'])

# %%
df = df.dropna(thresh=24)

# %%
df.isnull().sum()
# Out:
# danjigubn       0
# sedesu          0
# nambang         0
# sigog           0
# siheg           0
# gukag           0
# eill            0
# guard           0
# clean           0
# food            0
# water           0
# ellbe           0
# gisa            0
# giha            0
# cctv            0
# gucha           0
# amenitiesCnt    0
# areadaprice     0
# market          0
# school          0
# station         0
# bank            0
# cafe            0
# hospital        0
# dtype: int64

# %%
# 나중에 수치데이터로 바꿔줘야 할듯

# %%
df.loc[:,['danjigubn']] = df.loc[:,['danjigubn']].fillna('아파트')

# %%
df.isnull().sum()
# Out:
# danjigubn       0
# sedesu          0
# nambang         0
# sigog           0
# siheg           0
# gukag           0
# eill            0
# guard           0
# clean           0
# food            0
# water           0
# ellbe           0
# gisa            0
# giha            0
# cctv            0
# gucha           0
# amenitiesCnt    0
# areadaprice     0
# market          0
# school          0
# station         0
# bank            0
# cafe            0
# hospital        0
# dtype: int64

# %%
df.count()
# Out:
# danjigubn       1968
# sedesu          1968
# nambang         1968
# sigog           1968
# siheg           1968
# gukag           1968
# eill            1968
# guard           1968
# clean           1968
# food            1968
# water           1968
# ellbe           1968
# gisa            1968
# giha            1968
# cctv            1968
# gucha           1968
# amenitiesCnt    1968
# areadaprice     1968
# market          1968
# school          1968
# station         1968
# bank            1968
# cafe            1968
# hospital        1968
# dtype: int64

# %%
df['sigog'] = df['sigog'].str.replace('주','')

# %%
df["sigog"] = df["sigog"].str.replace(pat=r'[^\w]', repl=r'', regex=True)

# %%
df = df.dropna()
df.count()
# Out:
# danjigubn       1968
# sedesu          1968
# nambang         1968
# sigog           1968
# siheg           1968
# gukag           1968
# eill            1968
# guard           1968
# clean           1968
# food            1968
# water           1968
# ellbe           1968
# gisa            1968
# giha            1968
# cctv            1968
# gucha           1968
# amenitiesCnt    1968
# areadaprice     1968
# market          1968
# school          1968
# station         1968
# bank            1968
# cafe            1968
# hospital        1968
# dtype: int64

# %%
df['sigog'].value_counts()[:50]
# Out:
# 현대건설        115
# 삼성물산        103
# 현대산업개발       84
# 대우건설         62
# 대림산업         58
# 롯데건설         47
# 한신공영         47
# 우성건설         44
# 동부건설         38
# 두산건설         36
# GS건설         34
# 금호건설         30
# 신동아건설        26
# 대한택공사        24
# 쌍용건설         24
# 벽산건설         23
# 극동건설         22
# 중앙건설         21
# 경남기업         19
# 성원건설         18
# 동아건설         18
# 태영건설         17
# 삼성중공업        16
# 삼성건설         16
# 한화건설         16
# 건영           16
# 삼호           14
# 한양           13
# 이수건설         12
# 풍림산업         11
# SK건설         11
# 현대           11
# SH공사         10
# 한진중공업        10
# 삼익건설          9
# 월드건설          9
# 대림건설          9
# 청구            9
# 포스코건설         8
# 우방            8
# 유원건설          8
# 삼환기업          8
# 진흥기업          8
# 동아건설산업        8
# 한일건설          8
# 삼성물산건설부문      8
# 태영            8
# 대우            8
# 신동아           7
# 삼호건설          7
# Name: sigog, dtype: int64

# %%
# df.loc[~((df['sigog'] == '현대건설') | (df['sigog'] == '삼성물산') | (df['sigog']=='현대산업개발') | (df['sigog'] == '대우건설')), 'sigog'] = "other"

# %%
df.isnull().sum()
# Out:
# danjigubn       0
# sedesu          0
# nambang         0
# sigog           0
# siheg           0
# gukag           0
# eill            0
# guard           0
# clean           0
# food            0
# water           0
# ellbe           0
# gisa            0
# giha            0
# cctv            0
# gucha           0
# amenitiesCnt    0
# areadaprice     0
# market          0
# school          0
# station         0
# bank            0
# cafe            0
# hospital        0
# dtype: int64

# %%
df['sigog'].value_counts()
# Out:
# 현대건설                   115
# 삼성물산                   103
# 현대산업개발                  84
# 대우건설                    62
# 대림산업                    58
#                       ...
# HDC현대산업개발두산건설            1
# 신창건설                     1
# 삼중종합건설                   1
# 대우럭키개발롯데건설선경건설태평양건설      1
# 신도                       1
# Name: sigog, Length: 528, dtype: int64

# %%
categories = df.columns[df.dtypes=="object"]
print(categories)
# Out:
# Index(['danjigubn', 'nambang', 'sigog', 'siheg', 'gukag', 'food', 'water',
#        'gucha'],
#       dtype='object')

# %%
from sklearn.preprocessing import LabelEncoder

# %%
for cat in categories:
    le = LabelEncoder()
    print(cat)
    if df[cat].dtypes == "object":
        le = le.fit(df[cat])
        df[cat] = le.transform(df[cat])
# Out:
# danjigubn
# nambang
# sigog
# siheg
# gukag
# food
# water
# gucha

# %%
df.dtypes
# Out:
# danjigubn         int32
# sedesu            int64
# nambang           int32
# sigog             int32
# siheg             int32
# gukag             int32
# eill            float64
# guard           float64
# clean           float64
# food              int32
# water             int32
# ellbe           float64
# gisa            float64
# giha            float64
# cctv            float64
# gucha             int32
# amenitiesCnt      int64
# areadaprice     float64
# market            int64
# school            int64
# station           int64
# bank              int64
# cafe              int64
# hospital          int64
# dtype: object

# %%
df = df.drop(['sigog', 'siheg', 'gukag', 'gucha'], axis=1)

# %%
df = df.drop(['nambang'], axis=1)

# %%
df = df.drop(['cctv'], axis=1)

# %%
df_corr = df.corr()

# %%
df_corr
# Out:
#               danjigubn    sedesu      eill     guard     clean      food  \
# danjigubn      1.000000 -0.102403  0.100063 -0.016217  0.032912 -0.058822
# sedesu        -0.102403  1.000000  0.844472  0.764263  0.910014 -0.014146
# eill           0.100063  0.844472  1.000000  0.763826  0.909524 -0.040103
# guard         -0.016217  0.764263  0.763826  1.000000  0.721789 -0.007373
# clean          0.032912  0.910014  0.909524  0.721789  1.000000 -0.034020
# food          -0.058822 -0.014146 -0.040103 -0.007373 -0.034020  1.000000
# water          0.064977  0.055522  0.062411  0.023360  0.099837  0.009830
# ellbe         -0.100375  0.844491  0.753899  0.681255  0.823158 -0.034362
# gisa          -0.085730  0.519249  0.460738  0.692950  0.388048  0.020753
# giha           0.013744  0.727128  0.685469  0.389598  0.830080 -0.059129
# amenitiesCnt  -0.095840  0.316534  0.295748  0.138310  0.355541 -0.081603
# areadaprice   -0.006406  0.234834  0.329029  0.251880  0.332483 -0.066042
# market         0.048072  0.074258  0.122928  0.120345  0.093136 -0.036450
# school        -0.060146  0.119861  0.098939  0.109458  0.089415  0.047490
# station        0.174022 -0.013299  0.071209  0.039198  0.051513  0.001807
# bank           0.337924 -0.103256  0.005888 -0.032928 -0.028974 -0.026157
# cafe           0.275688 -0.144761 -0.052256 -0.071168 -0.070284 -0.020007
# hospital       0.168552 -0.016272  0.052126  0.050747  0.026109 -0.001865
#
#                  water     ellbe      gisa      giha  amenitiesCnt  \
# danjigubn     0.064977 -0.100375 -0.085730  0.013744     -0.095840
# sedesu        0.055522  0.844491  0.519249  0.727128      0.316534
# eill          0.062411  0.753899  0.460738  0.685469      0.295748
# guard         0.023360  0.681255  0.692950  0.389598      0.138310
# clean         0.099837  0.823158  0.388048  0.830080      0.355541
# food          0.009830 -0.034362  0.020753 -0.059129     -0.081603
# water         1.000000  0.098845 -0.066528  0.124861      0.188325
# ellbe         0.098845  1.000000  0.450749  0.698137      0.330359
# gisa         -0.066528  0.450749  1.000000 -0.078363     -0.050644
# giha          0.124861  0.698137 -0.078363  1.000000      0.419121
# amenitiesCnt  0.188325  0.330359 -0.050644  0.419121      1.000000
# areadaprice   0.087191  0.216604  0.045153  0.298910      0.265994
# market        0.025868  0.036509  0.072627  0.043545     -0.033793
# school       -0.027864  0.104442  0.090481  0.043329      0.029276
# station      -0.003128 -0.037682 -0.000076  0.026582     -0.017937
# bank          0.026598 -0.131232 -0.071119 -0.022283     -0.128361
# cafe          0.008116 -0.162486 -0.103426 -0.044730     -0.117408
# hospital      0.024010 -0.053268  0.029548 -0.006539     -0.112180
#
#               areadaprice    market    school   station      bank      cafe  \
# danjigubn       -0.006406  0.048072 -0.060146  0.174022  0.337924  0.275688
# sedesu           0.234834  0.074258  0.119861 -0.013299 -0.103256 -0.144761
# eill             0.329029  0.122928  0.098939  0.071209  0.005888 -0.052256
# guard            0.251880  0.120345  0.109458  0.039198 -0.032928 -0.071168
# clean            0.332483  0.093136  0.089415  0.051513 -0.028974 -0.070284
# food            -0.066042 -0.036450  0.047490  0.001807 -0.026157 -0.020007
# water            0.087191  0.025868 -0.027864 -0.003128  0.026598  0.008116
# ellbe            0.216604  0.036509  0.104442 -0.037682 -0.131232 -0.162486
# gisa             0.045153  0.072627  0.090481 -0.000076 -0.071119 -0.103426
# giha             0.298910  0.043545  0.043329  0.026582 -0.022283 -0.044730
# amenitiesCnt     0.265994 -0.033793  0.029276 -0.017937 -0.128361 -0.117408
# areadaprice      1.000000  0.271874  0.006033  0.274656  0.137235  0.153061
# market           0.271874  1.000000  0.126849  0.188516  0.293560  0.241141
# school           0.006033  0.126849  1.000000  0.021560 -0.072428 -0.134648
# station          0.274656  0.188516  0.021560  1.000000  0.414751  0.405498
# bank             0.137235  0.293560 -0.072428  0.414751  1.000000  0.725239
# cafe             0.153061  0.241141 -0.134648  0.405498  0.725239  1.000000
# hospital         0.224641  0.310698 -0.053233  0.283768  0.673596  0.624750
#
#               hospital
# danjigubn     0.168552
# sedesu       -0.016272
# eill          0.052126
# guard         0.050747
# clean         0.026109
# food         -0.001865
# water         0.024010
# ellbe        -0.053268
# gisa          0.029548
# giha         -0.006539
# amenitiesCnt -0.112180
# areadaprice   0.224641
# market        0.310698
# school       -0.053233
# station       0.283768
# bank          0.673596
# cafe          0.624750
# hospital      1.000000

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.figure(figsize=(15,15))
sns.heatmap(df_corr, vmax=1, vmin=-1, center=0, annot=True)
# Out:
# <AxesSubplot:>

# %%
train_df_le = df[~df['areadaprice'].isnull()]
test_df_le = df[df['areadaprice'].isnull()]

# %%
import lightgbm as lgb

# %%
from sklearn.model_selection import KFold
folds = 3
kf = KFold(n_splits = folds)

# %%
lgbm_params = {
    "objective":"regression",
    "random_seed":1234
}

# %%
train_X = train_df_le.drop(['areadaprice'], axis=1)
train_Y = train_df_le['areadaprice']

# %%
from sklearn.metrics import mean_squared_error

# %%
df.dtypes
# Out:
# danjigubn         int32
# sedesu            int64
# eill            float64
# guard           float64
# clean           float64
# food              int32
# water             int32
# ellbe           float64
# gisa            float64
# giha            float64
# amenitiesCnt      int64
# areadaprice     float64
# market            int64
# school            int64
# station           int64
# bank              int64
# cafe              int64
# hospital          int64
# dtype: object

# %%
models = []
rmses = []
oof = np.zeros(len(train_X))

for train_index, val_index in kf.split(train_X):
    X_train = train_X.iloc[train_index]
    X_valid = train_X.iloc[val_index]
    y_train = train_Y.iloc[train_index]
    y_valid = train_Y.iloc[val_index]
    
    lgb_train = lgb.Dataset(X_train, y_train)
    lgb_eval = lgb.Dataset(X_valid, y_valid, reference=lgb_train)
    
    model_lgb = lgb.train(lgbm_params,
                         lgb_train,
                          valid_sets = lgb_eval,
                         num_boost_round=100,
                         early_stopping_rounds=20,
                         verbose_eval = 10)
    
    y_pred = model_lgb.predict(X_valid, num_iteration=model_lgb.best_iteration)
    tmp_rmse = np.sqrt(mean_squared_error(np.log(y_valid), np.log(y_pred)))
    print(tmp_rmse)
    
    models.append(model_lgb)
    rmses.append(tmp_rmse)
    oof[val_index] = y_pred
# Out:
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000248 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1240
# [LightGBM] [Info] Number of data points in the train set: 1312, number of used features: 17
# [LightGBM] [Info] Start training from score 4090.772713
# Training until validation scores don't improve for 20 rounds
# [10]	valid_0's l2: 3.47161e+06
# [20]	valid_0's l2: 3.25339e+06
# [30]	valid_0's l2: 3.15062e+06
# [40]	valid_0's l2: 3.11931e+06
# [50]	valid_0's l2: 3.07873e+06
# [60]	valid_0's l2: 3.07802e+06
# [70]	valid_0's l2: 3.09126e+06
# [80]	valid_0's l2: 3.0923e+06
# Early stopping, best iteration is:
# [63]	valid_0's l2: 3.07729e+06
# 0.3470040880177704
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000145 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1256
# [LightGBM] [Info] Number of data points in the train set: 1312, number of used features: 17
# [LightGBM] [Info] Start training from score 4333.898094
# Training until validation scores don't improve for 20 rounds
# [10]	valid_0's l2: 1.72579e+06
# [20]	valid_0's l2: 1.5988e+06
# [30]	valid_0's l2: 1.56337e+06
# [40]	valid_0's l2: 1.54538e+06
# [50]	valid_0's l2: 1.54203e+06
# [60]	valid_0's l2: 1.52878e+06
# [70]	valid_0's l2: 1.53634e+06
# [80]	valid_0's l2: 1.53948e+06
# Early stopping, best iteration is:
# [60]	valid_0's l2: 1.52878e+06
# 0.2933393928432147
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000145 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1265
# [LightGBM] [Info] Number of data points in the train set: 1312, number of used features: 17
# [LightGBM] [Info] Start training from score 4329.950536
# Training until validation scores don't improve for 20 rounds
# [10]	valid_0's l2: 1.74273e+06
# [20]	valid_0's l2: 1.64247e+06
# [30]	valid_0's l2: 1.6177e+06
# [40]	valid_0's l2: 1.60951e+06
# [50]	valid_0's l2: 1.62395e+06
# Early stopping, best iteration is:
# [36]	valid_0's l2: 1.60118e+06
# 0.30182459557157965
# C:\Users\sonsj\anaconda3\lib\site-packages\lightgbm\engine.py:181: UserWarning: 'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. Pass 'early_stopping()' callback via 'callbacks' argument instead.
#   _log_warning("'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. "
# C:\Users\sonsj\anaconda3\lib\site-packages\lightgbm\engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# C:\Users\sonsj\anaconda3\lib\site-packages\lightgbm\engine.py:181: UserWarning: 'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. Pass 'early_stopping()' callback via 'callbacks' argument instead.
#   _log_warning("'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. "
# C:\Users\sonsj\anaconda3\lib\site-packages\lightgbm\engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# C:\Users\sonsj\anaconda3\lib\site-packages\lightgbm\engine.py:181: UserWarning: 'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. Pass 'early_stopping()' callback via 'callbacks' argument instead.
#   _log_warning("'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. "
# C:\Users\sonsj\anaconda3\lib\site-packages\lightgbm\engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "

# %%
for model in models:
    lgb.plot_importance(model, importance_type='gain', max_num_features=10)

# %%
actual_pred_df = pd.DataFrame({
    "actual": train_Y,
    "pred": oof
})

# %%
import matplotlib as plt

actual_pred_df.plot(figsize=(12,5))
# Out:
# <AxesSubplot:>

# %%
df['areadaprice'].describe()
# Out:
# count     1968.000000
# mean      4251.540447
# std       1737.241591
# min       1388.000000
# 25%       3032.375000
# 50%       3890.800000
# 75%       5054.625000
# max      12348.000000
# Name: areadaprice, dtype: float64

# %%
df['areadaprice'].plot.hist(bins=20)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
# 포아송 분포

# 잘 일어나지 않는 사건이 실제로 일어날 확률의 분포를 나타낼 때 이용하며, 좌우 대칭인 정규분포와 달리 왼쪽으로 치우침

# %%
# 목적 변수를 로그화 하기
# 일반적으로 머신 러닝이나 통계적인 처리의 대부분은 데이터가 정규 분포임을 상정하고 있다.

# %%
np.log(df['areadaprice']).plot.hist(bins=20)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
pd.options.mode.chained_assignment = None
train_df_le['areadaprice_log'] = np.log(train_df_le['areadaprice'])

# %%
train_X = train_df_le.drop(['areadaprice', 'areadaprice_log'], axis=1)
train_Y = train_df_le['areadaprice_log']

# %%
import warnings
warnings.filterwarnings("ignore")

models = []
rmses = []
oof = np.zeros(len(train_X))

for train_index, val_index in kf.split(train_X):
    X_train = train_X.iloc[train_index]
    X_valid = train_X.iloc[val_index]
    y_train = train_Y.iloc[train_index]
    y_valid = train_Y.iloc[val_index]
    
    lgb_train = lgb.Dataset(X_train, y_train)
    lgb_eval = lgb.Dataset(X_valid, y_valid, reference=lgb_train)
    
    model_lgb = lgb.train(lgbm_params,
                         lgb_train,
                          valid_sets = lgb_eval,
                         num_boost_round=100,
                         early_stopping_rounds=20,
                         verbose_eval = 10)
    
    y_pred = model_lgb.predict(X_valid, num_iteration=model_lgb.best_iteration)
    tmp_rmse = np.sqrt(mean_squared_error(y_valid, y_pred))
    print(tmp_rmse)
    
    models.append(model_lgb)
    rmses.append(tmp_rmse)
    oof[val_index] = y_pred
# Out:
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000244 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1240
# [LightGBM] [Info] Number of data points in the train set: 1312, number of used features: 17
# [LightGBM] [Info] Start training from score 8.253663
# Training until validation scores don't improve for 20 rounds
# [10]	valid_0's l2: 0.136093
# [20]	valid_0's l2: 0.127918
# [30]	valid_0's l2: 0.125444
# [40]	valid_0's l2: 0.123693
# [50]	valid_0's l2: 0.122771
# [60]	valid_0's l2: 0.12389
# [70]	valid_0's l2: 0.124546
# Early stopping, best iteration is:
# [50]	valid_0's l2: 0.122771
# 0.35038651765643364
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000150 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1256
# [LightGBM] [Info] Number of data points in the train set: 1312, number of used features: 17
# [LightGBM] [Info] Start training from score 8.296468
# Training until validation scores don't improve for 20 rounds
# [10]	valid_0's l2: 0.0912321
# [20]	valid_0's l2: 0.0837551
# [30]	valid_0's l2: 0.0817294
# [40]	valid_0's l2: 0.0812965
# [50]	valid_0's l2: 0.0813188
# Early stopping, best iteration is:
# [36]	valid_0's l2: 0.0811643
# 0.2848934718163431
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000145 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1265
# [LightGBM] [Info] Number of data points in the train set: 1312, number of used features: 17
# [LightGBM] [Info] Start training from score 8.296237
# Training until validation scores don't improve for 20 rounds
# [10]	valid_0's l2: 0.0941979
# [20]	valid_0's l2: 0.0897688
# [30]	valid_0's l2: 0.0870564
# [40]	valid_0's l2: 0.0862442
# [50]	valid_0's l2: 0.0866778
# Early stopping, best iteration is:
# [39]	valid_0's l2: 0.08597
# 0.29320636968914426

# %%
for model in models:
    lgb.plot_importance(model, importance_type='gain', max_num_features=5)

# %%
actual_pred_df = pd.DataFrame({
    "actual": train_Y,
    "pred": oof
})

# %%
import matplotlib as plt

actual_pred_df.plot(figsize=(12,5))
# Out:
# <AxesSubplot:>
